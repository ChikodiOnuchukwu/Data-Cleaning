# %%
import pandas as pd
pd.read_csv("covid vaccine-1.csv")

#comma seperated value
#commas are delimeter
# Out:
#            Region         State Total population  \
# 0      South East          Abia        3,727,347
# 1      North East       Adamawa        4,248,436
# 2     South South     Akwa Ibom        5,482,177
# 3      South East       Anambra        5,527,809
# 4      North East        Bauchi        6,537,314
# 5     South South       Bayelsa        2,277,961
# 6   North Central         Benue        5,741,815
# 7      North East         Borno        5,860,183
# 8     South South  Cross Rivets        3,866,269
# 9     South South           &&&        3,866,269
# 10    South South         Delta        5,663,362
# 11     South East        Ebonyi        2,880,383
# 12    South South           Edo        4,235,595
# 13     South West         Ekiti        3,270,798
# 14     South West          XXXX          230,900
# 15     South East         Enugu        4,411,119
# 16  North Central           FCT        3,564,126
# 17     North East         Gombe        3,256,962
# ...

# %%
vaccine = pd.read_csv("covid vaccine-1.csv")

# %%
vaccine
# Out:
#            Region         State Total population  \
# 0      South East          Abia        3,727,347
# 1      North East       Adamawa        4,248,436
# 2     South South     Akwa Ibom        5,482,177
# 3      South East       Anambra        5,527,809
# 4      North East        Bauchi        6,537,314
# 5     South South       Bayelsa        2,277,961
# 6   North Central         Benue        5,741,815
# 7      North East         Borno        5,860,183
# 8     South South  Cross Rivets        3,866,269
# 9     South South           &&&        3,866,269
# 10    South South         Delta        5,663,362
# 11     South East        Ebonyi        2,880,383
# 12    South South           Edo        4,235,595
# 13     South West         Ekiti        3,270,798
# 14     South West          XXXX          230,900
# 15     South East         Enugu        4,411,119
# 16  North Central           FCT        3,564,126
# 17     North East         Gombe        3,256,962
# ...

# %%
vaccine.dtypes
# Out:
# Region                                 object
# State                                  object
# Total population                       object
# Total Doses Administered (Astra)       object
# Total Doses Administered (Moderna)     object
# Total Doses Administered              float64
# dtype: object

# %%
#remove the commma in the population and the total dose administered 
vaccine[["Total population","Total Doses Administered (Astra)"]]
# Out:
#    Total population Total Doses Administered (Astra)
# 0         3,727,347                           61,152
# 1         4,248,436                           70,521
# 2         5,482,177                           67,760
# 3         5,527,809                           62,171
# 4         6,537,314                           98,409
# 5         2,277,961                           31,800
# 6         5,741,815                          107,094
# 7         5,860,183                           64,623
# 8         3,866,269                           99,813
# 9         3,866,269                              NaN
# 10        5,663,362                           88,631
# 11        2,880,383                           46,696
# 12        4,235,595                           76,360
# 13        3,270,798                          108,118
# 14          230,900                           47,000
# 15        4,411,119                           69,626
# 16        3,564,126                          254,088
# ...

# %%
vaccine["Total population"].str.replace(",","")
# Out:
# 0      3727347
# 1      4248436
# 2      5482177
# 3      5527809
# 4      6537314
# 5      2277961
# 6      5741815
# 7      5860183
# 8      3866269
# 9      3866269
# 10     5663362
# 11     2880383
# 12     4235595
# 13     3270798
# 14      230900
# 15     4411119
# 16     3564126
# 17     3256962
# 18         NaN
# 19     5408756
# 20     5828163
# 21     8252366
# 22    15076892
# 23     7831319
# 24     4440050
# 25     4473490
# 26     4567888
# 27     3192893
# 28    12000598
# 29     2523395
# 30     5556247
# 31     5217716
# 32     4671695
# 33     4705589
# 34     7840864
# 35     4200442
# 36     7303924
# 37     4567888
# 38     4998090
# 39     3066834
# 40     3294137
# 41     4515427
# Name: Total population, dtype: object

# %%
#using a regular expression

vaccine.pop("Total Doses Administered")
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# 30   NaN
# 31   NaN
# 32   NaN
# 33   NaN
# 34   NaN
# 35   NaN
# 36   NaN
# 37   NaN
# 38   NaN
# 39   NaN
# 40   NaN
# 41   NaN
# Name: Total Doses Administered, dtype: float64

# %%
# \w is used to remove all characters that are neither text nor numbers
# \w is used to remove all characters that are neither text and numbers

vaccine['Total population'].str.replace("\W","")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6096\533630982.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   vaccine['Total population'].str.replace("\W","")
# 0      3727347
# 1      4248436
# 2      5482177
# 3      5527809
# 4      6537314
# 5      2277961
# 6      5741815
# 7      5860183
# 8      3866269
# 9      3866269
# 10     5663362
# 11     2880383
# 12     4235595
# 13     3270798
# 14      230900
# 15     4411119
# 16     3564126
# 17     3256962
# 18         NaN
# 19     5408756
# 20     5828163
# 21     8252366
# 22    15076892
# 23     7831319
# 24     4440050
# 25     4473490
# 26     4567888
# 27     3192893
# 28    12000598
# 29     2523395
# 30     5556247
# 31     5217716
# 32     4671695
# 33     4705589
# 34     7840864
# 35     4200442
# 36     7303924
# 37     4567888
# 38     4998090
# 39     3066834
# 40     3294137
# 41     4515427
# Name: Total population, dtype: object

# %%
vaccine["State"].str.replace("\W","",regex=True)

#regex=True will remove the warning telling Pandas you are using a regular expression on the column
# Out:
# 0            Abia
# 1         Adamawa
# 2        AkwaIbom
# 3         Anambra
# 4          Bauchi
# 5         Bayelsa
# 6           Benue
# 7           Borno
# 8     CrossRivets
# 9
# 10          Delta
# 11         Ebonyi
# 12            Edo
# 13          Ekiti
# 14           XXXX
# 15          Enugu
# 16            FCT
# 17          Gombe
# 18
# 19            Imo
# 20         Jigawa
# 21         Kaduna
# 22           Kano
# 23        Katsina
# 24          Kebbi
# 25           Kogi
# 26            NaN
# 27          Kwara
# 28          Lagos
# 29      Nassarawa
# 30          Niger
# 31           Ogun
# 32           Ondo
# 33           Osun
# 34            Oyo
# 35        Plateau
# 36         Rivers
# 37           XXXX
# 38         Sokoto
# 39         Taraba
# 40           Yobe
# 41        Zamfara
# Name: State, dtype: object

# %%
#replacing the comma with an empty string (nothing)
#re-asign the values without the comma to the orignal dataframe

vaccine["Total population"]=vaccine["Total population"].str.replace(",","")
vaccine
# Out:
#            Region         State Total population  \
# 0      South East          Abia          3727347
# 1      North East       Adamawa          4248436
# 2     South South     Akwa Ibom          5482177
# 3      South East       Anambra          5527809
# 4      North East        Bauchi          6537314
# 5     South South       Bayelsa          2277961
# 6   North Central         Benue          5741815
# 7      North East         Borno          5860183
# 8     South South  Cross Rivets          3866269
# 9     South South           &&&          3866269
# 10    South South         Delta          5663362
# 11     South East        Ebonyi          2880383
# 12    South South           Edo          4235595
# 13     South West         Ekiti          3270798
# 14     South West          XXXX           230900
# 15     South East         Enugu          4411119
# 16  North Central           FCT          3564126
# 17     North East         Gombe          3256962
# ...

# %%
vaccine["State"]=vaccine["State"].str.replace("\W,","",regex=True)

vaccine
# Out:
#            Region         State Total population  \
# 0      South East          Abia          3727347
# 1      North East       Adamawa          4248436
# 2     South South     Akwa Ibom          5482177
# 3      South East       Anambra          5527809
# 4      North East        Bauchi          6537314
# 5     South South       Bayelsa          2277961
# 6   North Central         Benue          5741815
# 7      North East         Borno          5860183
# 8     South South  Cross Rivets          3866269
# 9     South South           &&&          3866269
# 10    South South         Delta          5663362
# 11     South East        Ebonyi          2880383
# 12    South South           Edo          4235595
# 13     South West         Ekiti          3270798
# 14     South West          XXXX           230900
# 15     South East         Enugu          4411119
# 16  North Central           FCT          3564126
# 17     North East         Gombe          3256962
# ...

# %%
vaccine['Total Doses Administered (Astra)'].str.replace("\W","")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6096\3994280494.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   vaccine['Total Doses Administered (Astra)'].str.replace("\W","")
# 0      61152
# 1      70521
# 2      67760
# 3      62171
# 4      98409
# 5      31800
# 6     107094
# 7      64623
# 8      99813
# 9        NaN
# 10     88631
# 11     46696
# 12     76360
# 13    108118
# 14     47000
# 15     69626
# 16    254088
# 17     92502
# 18       145
# 19     63326
# 20     80145
# 21    180598
# 22    184448
# 23    110522
# 24     62558
# 25     45537
# 26      7800
# 27    115042
# 28    669996
# 29     81416
# 30     95799
# 31    191969
# 32    100249
# 33    100684
# 34    169523
# 35    103275
# 36    121889
# 37        43
# 38     52648
# 39     60613
# 40     49079
# 41     68517
# Name: Total Doses Administered (Astra), dtype: object

# %%
vaccine['Total Doses Administered (Astra)'] = vaccine['Total Doses Administered (Astra)'].str.replace("\W","")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6096\3631136123.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   vaccine['Total Doses Administered (Astra)'] = vaccine['Total Doses Administered (Astra)'].str.replace("\W","")

# %%
vaccine
# Out:
#            Region         State Total population  \
# 0      South East          Abia          3727347
# 1      North East       Adamawa          4248436
# 2     South South     Akwa Ibom          5482177
# 3      South East       Anambra          5527809
# 4      North East        Bauchi          6537314
# 5     South South       Bayelsa          2277961
# 6   North Central         Benue          5741815
# 7      North East         Borno          5860183
# 8     South South  Cross Rivets          3866269
# 9     South South           &&&          3866269
# 10    South South         Delta          5663362
# 11     South East        Ebonyi          2880383
# 12    South South           Edo          4235595
# 13     South West         Ekiti          3270798
# 14     South West          XXXX           230900
# 15     South East         Enugu          4411119
# 16  North Central           FCT          3564126
# 17     North East         Gombe          3256962
# ...

# %%
#dropna() drop any row that has NaN
#dropping, inserting, sorting, we use implace=True to make permanent to thedataframe

vaccine.dropna()
# Out:
#            Region         State Total population  \
# 0      South East          Abia          3727347
# 1      North East       Adamawa          4248436
# 2     South South     Akwa Ibom          5482177
# 3      South East       Anambra          5527809
# 4      North East        Bauchi          6537314
# 5     South South       Bayelsa          2277961
# 6   North Central         Benue          5741815
# 7      North East         Borno          5860183
# 8     South South  Cross Rivets          3866269
# 10    South South         Delta          5663362
# 11     South East        Ebonyi          2880383
# 12    South South           Edo          4235595
# 13     South West         Ekiti          3270798
# 14     South West          XXXX           230900
# 15     South East         Enugu          4411119
# 16  North Central           FCT          3564126
# 17     North East         Gombe          3256962
# 19     South East           Imo          5408756
# ...

# %%
#fillna()

#fillna()  fills empty NaN cells

vaccine.fillna(0,inplace=True)

# %%
vaccine
# Out:
#            Region         State Total population  \
# 0      South East          Abia          3727347
# 1      North East       Adamawa          4248436
# 2     South South     Akwa Ibom          5482177
# 3      South East       Anambra          5527809
# 4      North East        Bauchi          6537314
# 5     South South       Bayelsa          2277961
# 6   North Central         Benue          5741815
# 7      North East         Borno          5860183
# 8     South South  Cross Rivets          3866269
# 9     South South           &&&          3866269
# 10    South South         Delta          5663362
# 11     South East        Ebonyi          2880383
# 12    South South           Edo          4235595
# 13     South West         Ekiti          3270798
# 14     South West          XXXX           230900
# 15     South East         Enugu          4411119
# 16  North Central           FCT          3564126
# 17     North East         Gombe          3256962
# ...

# %%
vaccine.dtypes
# Out:
# Region                                object
# State                                 object
# Total population                      object
# Total Doses Administered (Astra)      object
# Total Doses Administered (Moderna)    object
# dtype: object

# %%
vaccine.replace(to_replace=["XXXXX","XXXX"], value=[0,0],inplace=True)

#replacing in the whole dataframe

# %%
vaccine
# Out:
#            Region         State Total population  \
# 0      South East          Abia          3727347
# 1      North East       Adamawa          4248436
# 2     South South     Akwa Ibom          5482177
# 3      South East       Anambra          5527809
# 4      North East        Bauchi          6537314
# 5     South South       Bayelsa          2277961
# 6   North Central         Benue          5741815
# 7      North East         Borno          5860183
# 8     South South  Cross Rivets          3866269
# 9     South South           &&&          3866269
# 10    South South         Delta          5663362
# 11     South East        Ebonyi          2880383
# 12    South South           Edo          4235595
# 13     South West         Ekiti          3270798
# 14     South West             0           230900
# 15     South East         Enugu          4411119
# 16  North Central           FCT          3564126
# 17     North East         Gombe          3256962
# ...

# %%
#converting the 3 columns to integars

vaccine[["Total population","Total Doses Administered (Astra)","Total Doses Administered (Moderna)"]].astype(int)
# Out:
#     Total population  Total Doses Administered (Astra)  \
# 0            3727347                             61152
# 1            4248436                             70521
# 2            5482177                             67760
# 3            5527809                             62171
# 4            6537314                             98409
# 5            2277961                             31800
# 6            5741815                            107094
# 7            5860183                             64623
# 8            3866269                             99813
# 9            3866269                                 0
# 10           5663362                             88631
# 11           2880383                             46696
# 12           4235595                             76360
# 13           3270798                            108118
# 14            230900                             47000
# 15           4411119                             69626
# ...

# %%
vaccine[["Total population","Total Doses Administered (Astra)","Total Doses Administered (Moderna)"]] = vaccine[["Total population","Total Doses Administered (Astra)","Total Doses Administered (Moderna)"]].astype(int)

# %%
vaccine
# Out:
#            Region         State  Total population  \
# 0      South East          Abia           3727347
# 1      North East       Adamawa           4248436
# 2     South South     Akwa Ibom           5482177
# 3      South East       Anambra           5527809
# 4      North East        Bauchi           6537314
# 5     South South       Bayelsa           2277961
# 6   North Central         Benue           5741815
# 7      North East         Borno           5860183
# 8     South South  Cross Rivets           3866269
# 9     South South           &&&           3866269
# 10    South South         Delta           5663362
# 11     South East        Ebonyi           2880383
# 12    South South           Edo           4235595
# 13     South West         Ekiti           3270798
# 14     South West             0            230900
# 15     South East         Enugu           4411119
# 16  North Central           FCT           3564126
# 17     North East         Gombe           3256962
# ...

# %%
vaccine.dtypes
# Out:
# Region                                object
# State                                 object
# Total population                       int32
# Total Doses Administered (Astra)       int32
# Total Doses Administered (Moderna)     int32
# dtype: object

# %%
vaccine["Total(Astra and Moderna)"] = ""

# %%
vaccine
# Out:
#            Region         State  Total population  \
# 0      South East          Abia           3727347
# 1      North East       Adamawa           4248436
# 2     South South     Akwa Ibom           5482177
# 3      South East       Anambra           5527809
# 4      North East        Bauchi           6537314
# 5     South South       Bayelsa           2277961
# 6   North Central         Benue           5741815
# 7      North East         Borno           5860183
# 8     South South  Cross Rivets           3866269
# 9     South South           &&&           3866269
# 10    South South         Delta           5663362
# 11     South East        Ebonyi           2880383
# 12    South South           Edo           4235595
# 13     South West         Ekiti           3270798
# 14     South West             0            230900
# 15     South East         Enugu           4411119
# 16  North Central           FCT           3564126
# 17     North East         Gombe           3256962
# ...

# %%
vaccine[["Total Doses Administered (Astra)","Total Doses Administered (Moderna)"]].sum(axis=1)
# Out:
# 0      86324
# 1     106823
# 2      94934
# 3      76045
# 4     141571
# 5      41096
# 6     167350
# 7      96501
# 8     151375
# 9      51562
# 10    112865
# 11     65260
# 12    136140
# 13    155536
# 14     52000
# 15     79230
# 16    288934
# 17    109904
# 18       145
# 19     78908
# 20    124399
# 21    224110
# 22    252208
# 23    156428
# 24     93148
# 25     61581
# 26     52754
# 27    159996
# 28    906218
# 29    121512
# 30    141913
# 31    273785
# 32    174309
# 33    153618
# 34    244493
# 35    131261
# 36    168047
# 37        43
# 38     70652
# 39     87647
# 40     71857
# 41    101011
# dtype: int64

# %%
vaccine["Total(Astra and Moderna)"]=vaccine[["Total Doses Administered (Astra)","Total Doses Administered (Moderna)"]].sum(axis=1)

# %%
vaccine
# Out:
#            Region         State  Total population  \
# 0      South East          Abia           3727347
# 1      North East       Adamawa           4248436
# 2     South South     Akwa Ibom           5482177
# 3      South East       Anambra           5527809
# 4      North East        Bauchi           6537314
# 5     South South       Bayelsa           2277961
# 6   North Central         Benue           5741815
# 7      North East         Borno           5860183
# 8     South South  Cross Rivets           3866269
# 9     South South           &&&           3866269
# 10    South South         Delta           5663362
# 11     South East        Ebonyi           2880383
# 12    South South           Edo           4235595
# 13     South West         Ekiti           3270798
# 14     South West             0            230900
# 15     South East         Enugu           4411119
# 16  North Central           FCT           3564126
# 17     North East         Gombe           3256962
# ...
